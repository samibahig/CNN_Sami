# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/CNN_Sami/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.transforms


from_numpy = torch.from_numpy
batch_size = 32
num_epochs = 10
store_every = 700
lr0 = 0.03
#model_type = 'MLP'
model_type = 'CNN'
mnist_transforms = torchvision.transforms.Compose(
        [torchvision.transforms.ToTensor()])
mnist_train = torchvision.datasets.MNIST(
        root='./data', train=True, 
        transform=mnist_transforms, download=True)
mnist_test = torchvision.datasets.MNIST(
        root='./data', train=False, 
        transform=mnist_transforms, download=True)

train_loader = torch.utils.data.DataLoader(
        mnist_train, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(
        mnist_test, batch_size=batch_size, shuffle=True, num_workers=2)

class ResLinear(nn.Module):

    def __init__(self, in_features, out_features, activation=nn.ReLU()):
        super(ResLinear, self).__init__()
        
        self.in_features = in_features
        self.out_features = out_features
        self.activation = activation
        
        self.linear = nn.Linear(in_features, out_features)
        if in_features != out_features:
            self.project_linear = nn.Linear(in_features, out_features)
        
    def forward(self, x):
        inner = self.activation(self.linear(x))
        if self.in_features != self.out_features:
            skip = self.project_linear(x)
        else:
            skip = x
        return inner + skip


class Flatten(nn.Module):
    def forward(self, x):
        x = x.view(x.size(0), -1)
        return x

if model_type == 'CNN':
  model = nn.Sequential(nn.Conv2d(1,100,3),
        nn.ReLU(),
        nn.MaxPool2d(2),
        nn.Conv2d(100,122,5),
        nn.ReLU(),
        nn.MaxPool2d(2),
        Flatten(),
        ResLinear(1952, 100),
        nn.ReLU(),
        ResLinear(100, 10)
    )

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr0)

#Learning rate
def adjust_lr(optimizer, epoch, total_epochs):
    lr = lr0 * (0.1 ** (epoch / float(total_epochs)))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

#Evalution Functions
def accuracy(proba, y):
    correct = torch.eq(proba.max(1)[1], y).sum().type(torch.FloatTensor)
    return correct / y.size(0)
    
    
def evaluate(dataset_loader, criterion):
    LOSSES = 0
    COUNTER = 0
    for batch in dataset_loader:
        optimizer.zero_grad()
        x,y = batch
        if model_type == 'CNN':
            x = x.view(-1,1,28,28)
            y = y.view(-1)
          
        loss = criterion(model(x), y)
        n = y.size(0)
        LOSSES += loss.sum().data.cpu().numpy() * n
        COUNTER += n
    return LOSSES / float(COUNTER)

#Training loop
LOSSES = 0
COUNTER = 0
ITERATIONS = 0
train_losses = [] # save loss
train_accuracy =[] #save accuracy
tess_accuracy =[] #save accuracy
test_losses =[] #save accuracy

learning_curve_nll_train = list()
learning_curve_nll_test = list()
learning_curve_acc_train = list()
learning_curve_acc_test = list()
for e in range(num_epochs):
    print('Epoch', e+1)
    for batch in train_loader:
        optimizer.zero_grad()
        x,y = batch
        if model_type == 'CNN':
            x = x.view(-1,1,28,28)
            y = y.view(-1)
            
        loss = criterion(model(x), y)
        loss.backward()
        optimizer.step()
        
        n = y.size(0)
        LOSSES += loss.sum().data.cpu().numpy() * n
        COUNTER += n
        ITERATIONS += 1
        if ITERATIONS%(store_every/5) == 0:
            avg_loss = LOSSES / float(COUNTER)
            LOSSES = 0
            COUNTER = 0
            print(" Iteration {}: TRAIN {}".format(
                ITERATIONS, avg_loss))
    
        if ITERATIONS%(store_every) == 0 or ITERATIONS%(938) == 0 :     
            train_loss = evaluate(train_loader, criterion)
            learning_curve_nll_train.append(train_loss)
            test_loss = evaluate(test_loader, criterion)
            learning_curve_nll_test.append(test_loss)

            train_acc = evaluate(train_loader, accuracy)
            learning_curve_acc_train.append(train_acc)
            test_acc = evaluate(test_loader, accuracy)
            learning_curve_acc_test.append(test_acc)
                    
            print(" [NLL] TRAIN {} / TEST {}".format(
                train_loss, test_loss))
            print(" [ACC] TRAIN {} / TEST {}".format(
                train_acc, test_acc))
    
    train_accuracy.append(train_acc)
    train_losses.append(train_loss)
    tess_accuracy.append(test_acc)
    test_losses.append(test_loss)
    learning_curve_nll_test.append(test_loss)
    print('Train accuracy', train_accuracy)
    print('Train Loss', train_loss)
    print('Train test accurary', test_loss)
    print('Train accuracy', test_acc)
    print(ITERATIONS)
    print('learning_curve_nll_test', test_loss)

    
    adjust_lr(optimizer, e+1, num_epochs)
# Out:
# Epoch 1
#  Iteration 140: TRAIN 1.060780677092927
#  Iteration 280: TRAIN 0.3206376375630498
#  Iteration 420: TRAIN 0.2130424170887896
#  Iteration 560: TRAIN 0.1511570948575224
#  Iteration 700: TRAIN 0.1582777353136667
#  [NLL] TRAIN 0.1251993427998076 / TEST 0.11931992106735706
#  [ACC] TRAIN 0.9625 / TEST 0.9651
#  Iteration 840: TRAIN 0.14134512222371995
#  [NLL] TRAIN 0.12331756992762287 / TEST 0.11693584402650595
#  [ACC] TRAIN 0.9598 / TEST 0.9612
#  Iteration 980: TRAIN 0.12275138921769602
#  Iteration 1120: TRAIN 0.11554715045993881
#  Iteration 1260: TRAIN 0.10680253602830427
#  Iteration 1400: TRAIN 0.11002847783467067
#  [NLL] TRAIN 0.08625302968186636 / TEST 0.07777049035131932
#  [ACC] TRAIN 0.9731833333333333 / TEST 0.975
#  Iteration 1540: TRAIN 0.091537536278234
#  Iteration 1680: TRAIN 0.08708197405295713
#  Iteration 1820: TRAIN 0.09162757418317986
# Train accuracy [0.9731833333333333]
# Train Loss 0.08625302968186636
# Train test accurary 0.07777049035131932
# Train accuracy 0.975
# 1875
# learning_curve_nll_test 0.07777049035131932
# Epoch 2
#  [NLL] TRAIN 0.06617572425873951 / TEST 0.055893115931749345
#  [ACC] TRAIN 0.9790166666666666 / TEST 0.982
#  Iteration 1960: TRAIN 0.06472176770579868
#  Iteration 2100: TRAIN 0.07312507437475557
#  [NLL] TRAIN 0.059558679797376196 / TEST 0.05267360747829079
#  [ACC] TRAIN 0.9818166666666667 / TEST 0.9837
#  Iteration 2240: TRAIN 0.0665586678494167
#  Iteration 2380: TRAIN 0.06739267479528539
#  Iteration 2520: TRAIN 0.05632854855419802
#  Iteration 2660: TRAIN 0.05365229535465395
#  Iteration 2800: TRAIN 0.06570587100951733
#  [NLL] TRAIN 0.057261726856666306 / TEST 0.055821618228033186
#  [ACC] TRAIN 0.9823 / TEST 0.9827
#  [NLL] TRAIN 0.0630513394686083 / TEST 0.06070133029222488
#  Iteration 17780: TRAIN 0.018926641361810784
#  [NLL] TRAIN 0.014355703435919713 / TEST 0.025017111051874236
#  [ACC] TRAIN 0.9962833333333333 / TEST 0.9913
#  Iteration 17920: TRAIN 0.016125542151036953
#  Iteration 18060: TRAIN 0.012769851570348172
#  Iteration 18200: TRAIN 0.016052272459325778
#  [NLL] TRAIN 0.013884056568518282 / TEST 0.025056308398488908
#  [ACC] TRAIN 0.9966 / TEST 0.9914
#  Iteration 18340: TRAIN 0.012413858228787182
#  Iteration 18480: TRAIN 0.015318577619785044
#  Iteration 18620: TRAIN 0.013027297821827233
# Train accuracy [0.9731833333333333, 0.9866166666666667, 0.9859333333333333, 0.9907, 0.9938166666666667, 0.9939833333333333, 0.9944, 0.9954166666666666, 0.99595, 0.9966]
# Train Loss 0.013884056568518282
# Train test accurary 0.025056308398488908
# Train accuracy 0.9914
# 18750
# learning_curve_nll_test 0.025056308398488908

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary


device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # PyTorch v0.4.0
#model = net.to(device)
summary(model, (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 100, 26, 26]           1,000
#               ReLU-2          [-1, 100, 26, 26]               0
#          MaxPool2d-3          [-1, 100, 13, 13]               0
#             Conv2d-4            [-1, 122, 9, 9]         305,122
#               ReLU-5            [-1, 122, 9, 9]               0
#          MaxPool2d-6            [-1, 122, 4, 4]               0
#            Flatten-7                 [-1, 1952]               0
#             Linear-8                  [-1, 100]         195,300
#               ReLU-9                  [-1, 100]               0
#              ReLU-10                  [-1, 100]               0
#            Linear-11                  [-1, 100]         195,300
#         ResLinear-12                  [-1, 100]               0
#              ReLU-13                  [-1, 100]               0
#            Linear-14                   [-1, 10]           1,010
#              ReLU-15                   [-1, 10]               0
#              ReLU-16                   [-1, 10]               0
#            Linear-17                   [-1, 10]           1,010
#         ResLinear-18                   [-1, 10]               0
# ================================================================
# Total params: 698,742
# Trainable params: 698,742
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.35
# Params size (MB): 2.67
# Estimated Total Size (MB): 4.01
# ----------------------------------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
loss = [0.07777049035131932, 0.041443217152170836, 0.04799971681386232, 0.0325480570577085, 0.02741106542237103, 0.02913096259762533, 0.027385963300894947, 0.026436505250586197, 0.026238243733393028, 0.025056308398488908]
learning_curve_nll_test = [0.08625302968186636, 0.045440314386226234 , 0.045515671495875966 , 0.03080038878947186 , 0.021476109885176023, 0.020725537955240970, 0.019011080848080262, 0.016579115184869927 , 0.015197785850517297, 0.013884056568518282 ]
cnt=np.arange(10)
plt.plot(cnt, loss, label="Training loss")
plt.legend(loc="upper right")
plt.plot(cnt, learning_curve_nll_test, label="Validation loss")
plt.legend(loc="upper right")
plt.title("Training loss and Validation loss (batch_size=64, lr=0.02)")
plt.xlabel("Iterations")
plt.ylabel("loss")
plt.show()

Accuracy = [0.9704333333333334, 0.9835333333333334, 0.9885666666666667, 0.9922333333333333, 0.9936166666666667, 0.9935833333333334, 0.9953666666666666, 0.9947166666666667, 0.9965166666666667, 0.99665]
plt.plot(cnt,Accuracy)
plt.title("Training Accuracy Curve (batch_size=64, lr=0.02)")
plt.xlabel("Iterations")
plt.ylabel("Training Accuracy")
plt.show()
